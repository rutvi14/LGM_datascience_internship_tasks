# %% [markdown]
# # Task 3 - EDA on Terrorism

# %% [markdown]
# ## Name - Rutvi Rajesh

# %% [markdown]
# ## LGMVIP data science internship

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config IPCompleter.greedy=True

# %%
df = pd.read_csv('data.csv',encoding='latin1')
# Out:
# c:\users\hp\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.isnull().sum() #check for null values
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# Rename the columns and give proper names

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df.columns #columns are successfully renamed
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# Remove unnecessary columns

# %%
df = df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
df.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %% [markdown]
# Country,state,city max attacks

# %%
df['Country'].value_counts()
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# North Korea                1
# Antigua and Barbuda        1
# International              1
# New Hebrides               1
# Vatican City               1
# Name: Country, Length: 205, dtype: int64

# %%
print("Country with max attacks : ",df['Country'].value_counts().idxmax())
# Out:
# Country with max attacks :  Iraq

# %%
print("State with max attacks : ",df['state'].value_counts().idxmax())
# Out:
# State with max attacks :  Baghdad

# %%
print("city with max attacks : ",df['city'].value_counts().idxmax())
# Out:
# city with max attacks :  Unknown

# %%
df['city'].value_counts() #types of city avaialable in dataset
# Out:
# Unknown       9775
# Baghdad       7589
# Karachi       2652
# Lima          2359
# Mosul         2265
#               ...
# Bambangu         1
# Sabiqiyah        1
# Kendev           1
# Bhalukbasa       1
# Gorni            1
# Name: city, Length: 36674, dtype: int64

# %%
#as city at first index is unknown print next highest city 
print("city with max attacks : ",df['city'].value_counts().index[1])
# Out:
# city with max attacks :  Baghdad

# %%
print("Month with max attacks : ",df['Month'].value_counts().idxmax())
# Out:
# Month with max attacks :  5

# %%
df['Group'].value_counts() #types of Groups
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Union of Democratic Forces                              1
# People's Guerrilla Movement                             1
# Javier Heraud Revolutionary Commando                    1
# Ansar Ghazwat-ul-Hind                                   1
# Sympathizers of "Iranian People's Zeda'i"               1
# Name: Group, Length: 3537, dtype: int64

# %%
print("Group with max attacks : ",df['Group'].value_counts().idxmax())
# Out:
# Group with max attacks :  Unknown

# %%
df['AttackType'].value_counts() #types of attack
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
print("AttackType with max attacks : ",df['AttackType'].value_counts().idxmax())
# Out:
# AttackType with max attacks :  Bombing/Explosion

# %%
print("AttackType with max attacks : ",df['AttackType'].value_counts().idxmin()) #minimum attacktype
# Out:
# AttackType with max attacks :  Hijacking

# %%
df['Motive'].value_counts()
# Out:
# Unknown                                                                                                                                                                                               14889
# The specific motive for the attack is unknown.                                                                                                                                                        14430
# The specific motive is unknown; however, sources noted that the attack may have been part of a larger trend of violence related to Bangladesh's nationwide hartal, which began on January 6, 2015.      297
# The specific motive for the attack is unknown..                                                                                                                                                         148
# ...

# %%
print("Motive with max attacks : ",df['Motive'].value_counts().index[1]) 
#for maximum terror attack motive is unknow
# Out:
# Motive with max attacks :  The specific motive for the attack is unknown.

# %% [markdown]
# Wordcloud

# %%
df['Year'].value_counts(dropna = False).sort_index() #number of terror yearwise
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %%
print("Year with max attacks : ",df['Year'].value_counts().idxmax())
# Out:
# Year with max attacks :  2014

# %%
print("Year with max attacks : ",df['Year'].value_counts().idxmin())
# Out:
# Year with max attacks :  1971

# %%
from wordcloud import WordCloud
plt.subplots(figsize=(10,10))
attack = df.AttackType.dropna(False)
wordcloud = WordCloud(background_color = 'white',
                     width = 512,
                     height = 384).generate(' '.join(attack))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
df['AttackType']
# Out:
# 0                          Assassination
# 1            Hostage Taking (Kidnapping)
# 2                          Assassination
# 3                      Bombing/Explosion
# 4         Facility/Infrastructure Attack
#                        ...
# 181686                     Armed Assault
# 181687                 Bombing/Explosion
# 181688    Facility/Infrastructure Attack
# 181689                 Bombing/Explosion
# 181690                 Bombing/Explosion
# Name: AttackType, Length: 181691, dtype: object

# %%
plt.subplots(figsize=(10,10))
yr = df.Year.dropna(False)
yr = str(yr)
wordcloud = WordCloud(background_color = 'white',
                     width = 512,
                     height = 384).generate(' '.join(yr)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
#   File "<ipython-input-49-993500071d51>", line 7
#     plt.axis('off')
#       ^
# SyntaxError: invalid syntax

# %%
sns.countplot(y ='AttackType', data = df,order = df['AttackType'].value_counts().index)

# %%
plt.figure(figsize=(18,18))
sns.countplot(y ='Year', data = df,order = df['Year'].value_counts().index)

# %%
plt.figure(figsize=(10,10))
sns.countplot(y ='Weapon_type', data = df,order = df['Weapon_type'].value_counts().index)

# %%
plt.figure(figsize=(10,10))
sns.countplot(y ='Target_type', data = df,order = df['Target_type'].value_counts().index)

# %%
sns.regplot(x=df["Year"], y=df["Killed"]) #year vs number of persons killed

# %%
sns.lineplot(x="Year", y="Killed", data=df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# # Top 10 countries with maximum attacks

# %%
attacks = df.Country.value_counts()[:10]
attacks.plot.bar()

# %% [markdown]
# # Top 10 cities with maximum attacks

# %%
cities = df.city.value_counts()[:10]
cities.plot.bar()

# %% [markdown]
# # Top 10 terrorist groups

# %%
grp = df.Group.value_counts()[:10]
grp.plot.bar()

# %% [markdown]
# # Observations

# %% [markdown]
# ### Country with highest attacks - Iraq

# %% [markdown]
# ### City with highest attacks - Baghdad

# %% [markdown]
# ### Mostly attack type is - Bombing/Explosion

# %% [markdown]
# ### Group who does maximum terrorist attacks - Taliban

# %% [markdown]
# ### Year which has maximum attacks - 2014

# %% [markdown]
# ### Most target types are - Private Citizens & Property

# %% [markdown]
# # Thank You
